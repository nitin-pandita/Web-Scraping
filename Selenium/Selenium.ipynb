# %%
from selenium import webdriver

# %%
driver = webdriver.Chrome(executable_path='E:\Chrome Donwloads\chromedriver_win32/chromedriver')
driver
# Out:
# C:\Users\karti\AppData\Local\Temp\ipykernel_6548\4133824463.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path='E:\Chrome Donwloads\chromedriver_win32/chromedriver')
# <selenium.webdriver.chrome.webdriver.WebDriver (session="4d91e1862c22f2f36710db4a49870aa0")>

# %%
driver.get('https://www.javatpoint.com/box-cox-transformation-in-python')

# %%
driver.title
# Out:
# 'Box-Cox Transformation in Python - Javatpoint'

# %%
driver.back()

# %%
driver.forward()

# %%
driver.save_screenshot('screenshot.png')
# Out:
# True

# %%
driver.page_source
# Out:
# '<html lang="en"><head><script type="text/javascript" async="" src="https://static.criteo.net/js/ld/publishertag.prebid.117.js"></script><style class="vjs-styles-defaults">\n      .video-js {\n        width: 300px;\n        height: 150px;\n      }\n\n      .vjs-fluid:not(.vjs-audio-only-mode) {\n        padding-top: 56.25%\n      }\n    </style><style class="vjs-styles-dimensions">\n      .ap-player-dimensions {\n        width: 535px;\n        height: 300px;\n      }\n\n      .ap-player-dimensions.vjs-fluid:not(.vjs-audio-only-mode) {\n        padding-top: 56.25%;\n      }\n    </style><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><title>Box-Cox Transformation in Python - Javatpoint</title><link rel="SHORTCUT ICON" href="https://static.javatpoint.com/images/favicon2.png">\n<link rel="stylesheet" type="text/css" href="https://static.javatpoint.com/link.css?v=5.5" async=""><link rel="dns-prefetch" href="https://clients1.google.com"><link rel="dns-prefetch" href="ht
# ...

# %%
from selenium.webdriver.common.by import By

# %%
page = driver.find_element(By.LINK_TEXT, "Home")

# %%
page.click()
