# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup
import pandas as pd

# %%
driver = webdriver.Chrome('E:\Chrome Donwloads\chromedriver_win32/chromedriver')
# Out:
# C:\Users\karti\AppData\Local\Temp\ipykernel_5016\942410967.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('E:\Chrome Donwloads\chromedriver_win32/chromedriver')

# %%
driver.get('https://www.w3resource.com/sql-exercises/employee-database-exercise/sql-employee-database-exercise-69.php')

# %%
data = BeautifulSoup(driver.page_source)

# %%
data
# Out:
# <html class="mdl-js" lang="en" xmlns:fb="facebook.com/2008/fbml"><head>
# <meta charset="utf-8"/>
# <link href="/assets/mdl/material.min.css" rel="stylesheet" type="text/css"/>
# <link href="/assets/mdl/additional.css" rel="stylesheet" type="text/css"/>
# <meta content="width=device-width, initial-scale=1.0 " name="viewport"/>
# <link href="//www.w3resource.com/images/favicon.png" rel="shortcut icon"/>
# <title>SQL: Employees in the ascending order on annual salary</title>
# <meta content="SQL exercises on employee Database, online practice, w3resource" name="Keywords"/>
# <meta content="SQL exercises on employee Database, Practice and Solution: SQL query to rank the employees according to their annual salary in ascending order. " name="Description"/>
# <meta content="SQL: Employees in the ascending order on annual salary" property="og:title"/>
# ...

# %%
al = data.find(class_ = 'output')
al
# Out:
# <pre class="output" style="overflow: scroll;"> emp_id | emp_name | monthly_salary |     daily_salary     | anual_salary
# --------+----------+----------------+----------------------+--------------
#   63679 | SANDRINE |         900.00 |  30.0000000000000000 |     10800.00
#   69000 | JULIUS   |        1050.00 |  35.0000000000000000 |     12600.00
#   68736 | ADNRES   |        1200.00 |  40.0000000000000000 |     14400.00
#   65271 | WADE     |        1350.00 |  45.0000000000000000 |     16200.00
#   66564 | MADDEN   |        1350.00 |  45.0000000000000000 |     16200.00
#   69324 | MARKER   |        1400.00 |  46.6666666666666667 |     16800.00
#   68454 | TUCKER   |        1600.00 |  53.3333333333333333 |     19200.00
#   64989 | ADELYN   |        1700.00 |  56.6666666666666667 |     20400.00
#   67832 | CLARE    |        2550.00 |  85.0000000000000000 |     30600.00
#   66928 | BLAZE    |        2750.00 |  91.6666666666666667 |     33000.00
# ...

# %%
html_source = '''
<html>
  <body>
    <table>
      <tr>
        <th>Column 1</th>
        <th>Column 2</th>
      </tr>
      <tr>
        <td>Value 1</td>
        <td>Value 2</td>
      </tr>
    </table>
  </body>
</html>
'''

# %%
df = pd.read_html(str(html_source),header=0)
df[0]
# Out:
#   Column 1 Column 2
# 0  Value 1  Value 2
